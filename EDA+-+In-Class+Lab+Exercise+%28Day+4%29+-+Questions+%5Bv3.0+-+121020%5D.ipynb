# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#         <td width="15%">
#             <img src="GL-2.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b> Inclass - Lab <br>(Day 4)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### About the data set (Detected Cases of Malaria)
#
# This dataset consists of data for countries with an active malaria outbreak.
# <br>
#
# Attribute Information:
#
# **Cases_Guinea**: Number of cases of malaria reported from Guinea
#
# **Cases_Liberia**: Number of cases of malaria reported from Liberia
#
# **Cases_SierraLeone**: Number of cases of malaria reported from Sierra Leone
#
# **Cases_Nigeria**: Number of cases of malaria reported from Nigeria
#
# **Cases_Senegal**: Number of cases of malaria reported from Senegal
#
# **Cases_UnitedStates**: Number of cases of malaria reported from the United States of America
#
# **Cases_Spain**: Number of cases of malaria reported from Spain
#
# **Cases_Mali**: Number of cases of malaria reported from Mali
#
# **Deaths_Guinea**: Number of deaths reported out of the detected cases of malaria from Guinea
#
# **Deaths_Liberia**: Number of deaths reported out of the detected cases of malaria from Liberia
#
# **Deaths_SierraLeone**: Number of deaths reported out of the detected cases of malaria from Sierra Leone
#
# **Deaths_Nigeria**: Number of deaths reported out of the detected cases of malaria from Nigeria
#
# **Deaths_Senegal**: Number of deaths reported out of the detected cases of malaria from Senegal
#
# **Deaths_UnitedStates**: Number of deaths reported out of the detected cases of malaria from the United States of America
#
# **Deaths_Spain**: Number of deaths reported out of the detected cases of malaria from Spain
#
# **Deaths_Mali**: Number of deaths reported out of the detected cases of malaria from Mali

# %% [markdown]
# ##  Table of Content
#
# 1. **[Missing Values Detection](#msv)**
# 2. **[Handling Missing Values](#hmsv)**
# 3. **[Outlier Detection Techniques](#out)**
# 4. **[Treatment of Outliers](#odt)**
# 5. **[Feature Engineering](#fe)**
# 6. **[Train-Test Split](#split)**

# %% [markdown]
# **Import the required libraries**

# %%
# type your code here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy 
import warnings 
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Load the malaria dataset and display the first five records (Use for section 1, 2)

# %%
# type your code here
df=pd.read_csv('malaria.csv')
df.head()
# Out:
#    Cases_Guinea  Cases_Liberia  Cases_SierraLeone  Cases_Nigeria  \
# 0        2776.0            NaN            10030.0            NaN
# 1        2775.0            NaN             9780.0            NaN
# 2        2769.0         8166.0             9722.0            NaN
# 3           NaN         8157.0                NaN            NaN
# 4           NaN            NaN                NaN            NaN
#
#    Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  Deaths_Guinea  \
# 0            NaN                 NaN          NaN         NaN         1786.0
# 1            NaN                 NaN          NaN         NaN         1781.0
# 2            NaN                20.0          NaN         NaN         1767.0
# 3            NaN                10.0          NaN         NaN            NaN
# 4            NaN                 NaN          NaN         NaN            NaN
#
#    Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  Deaths_Senegal  \
# 0             NaN              2977.0             NaN             NaN
# 1             NaN              2943.0             NaN             NaN
# 2          3496.0              2915.0             NaN             NaN
# 3          3496.0                 NaN             NaN             NaN
# 4             NaN                 NaN             NaN             NaN
#
#    Deaths_UnitedStates  Deaths_Spain  Deaths_Mali
# 0                  NaN           NaN          NaN
# 1                  NaN           NaN          NaN
# 2                  3.0           NaN          NaN
# 3                  8.0           NaN          NaN
# 4                  NaN           NaN          NaN

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <a id="msv"> </a>
# ## 1. Missing Values Detection

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>1. Are there any records where no data has been reported?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
df.isnull().sum()/len(df)*100
# Out:
# Cases_Guinea           26.771654
# Cases_Liberia          34.645669
# Cases_SierraLeone      31.496063
# Cases_Nigeria          70.078740
# Cases_Senegal          80.314961
# Cases_UnitedStates     42.519685
# Cases_Spain            87.401575
# Cases_Mali             90.551181
# Deaths_Guinea          27.559055
# Deaths_Liberia         36.220472
# Deaths_SierraLeone     31.496063
# Deaths_Nigeria         70.078740
# Deaths_Senegal         82.677165
# Deaths_UnitedStates    55.118110
# Deaths_Spain           87.401575
# Deaths_Mali            90.551181
# dtype: float64

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>2. Find a list of all the columns which have more than 60% of their values missing</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
df1=df.isnull().sum()/len(df)*100
df1[df1>60]
# Out:
# Cases_Nigeria     70.078740
# Cases_Senegal     80.314961
# Cases_Spain       87.401575
# Cases_Mali        90.551181
# Deaths_Nigeria    70.078740
# Deaths_Senegal    82.677165
# Deaths_Spain      87.401575
# Deaths_Mali       90.551181
# dtype: float64

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3. In a scenario where one of the countries detected with malaria outbreak is to be recorded again for observations, which country should be considered first (consider only the first four countries)?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
df1.sort_values(ascending=False).iloc[0:4]
# Out:
# Cases_Mali      90.551181
# Deaths_Mali     90.551181
# Cases_Spain     87.401575
# Deaths_Spain    87.401575
# dtype: float64

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>4. Visualize the missing values in the data</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
plt.figure(figsize=(15,5),dpi=100)
sns.heatmap(df.isnull(),annot=True)
import missingno as msno
msno.heatmap(df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a id="hmsv"> </a>
# ## 2. Handling Missing Values

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>5. Eliminate all the records where no more than two observations have been recorded</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
df2=df.copy()
df2.dropna(axis=0,inplace=True,thresh=2)
df2.head()
# Out:
#    Cases_Guinea  Cases_Liberia  Cases_SierraLeone  Cases_Nigeria  \
# 0        2776.0            NaN            10030.0            NaN
# 1        2775.0            NaN             9780.0            NaN
# 2        2769.0         8166.0             9722.0            NaN
# 3           NaN         8157.0                NaN            NaN
# 5        2730.0         8115.0             9633.0            NaN
#
#    Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  Deaths_Guinea  \
# 0            NaN                 NaN          NaN         NaN         1786.0
# 1            NaN                 NaN          NaN         NaN         1781.0
# 2            NaN                20.0          NaN         NaN         1767.0
# 3            NaN                10.0          NaN         NaN            NaN
# 5            NaN                 7.0          NaN         NaN         1739.0
#
#    Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  Deaths_Senegal  \
# 0             NaN              2977.0             NaN             NaN
# 1             NaN              2943.0             NaN             NaN
# 2          3496.0              2915.0             NaN             NaN
# 3          3496.0                 NaN             NaN             NaN
# 5          3471.0              2827.0             NaN             NaN
#
#    Deaths_UnitedStates  Deaths_Spain  Deaths_Mali
# 0                  NaN           NaN          NaN
# 1                  NaN           NaN          NaN
# 2                  3.0           NaN          NaN
# 3                  8.0           NaN          NaN
# 5                  5.0           NaN          NaN

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>6. Cast aside the unnecessary columns from the data
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
df1=df2.isnull().sum()/len(df2)*100
df1[df1>50]
# Out:
# Cases_Nigeria          68.595041
# Cases_Senegal          79.338843
# Cases_Spain            86.776860
# Cases_Mali             90.082645
# Deaths_Nigeria         68.595041
# Deaths_Senegal         81.818182
# Deaths_UnitedStates    52.892562
# Deaths_Spain           86.776860
# Deaths_Mali            90.082645
# dtype: float64

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>7. How would you treat the missing values of the reported cases from Liberia?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
df2['Cases_Liberia']=df2['Cases_Liberia'].fillna(df2['Cases_Liberia'].median())
df2
# Out:
#      Cases_Guinea  Cases_Liberia  Cases_SierraLeone  Cases_Nigeria  \
# 0          2776.0          492.0            10030.0            NaN
# 1          2775.0          492.0             9780.0            NaN
# 2          2769.0         8166.0             9722.0            NaN
# 3             NaN         8157.0                NaN            NaN
# 5          2730.0         8115.0             9633.0            NaN
# ..            ...            ...                ...            ...
# 122         103.0            8.0                6.0            NaN
# 123          86.0          492.0                NaN            NaN
# 124          86.0          492.0                NaN            NaN
# 125          86.0          492.0                NaN            NaN
# 126          49.0          492.0                NaN            NaN
#
#      Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# 0              NaN                 NaN          NaN         NaN
# 1              NaN                 NaN          NaN         NaN
# 2              NaN                20.0          NaN         NaN
# 3              NaN                10.0          NaN         NaN
# 5              NaN                 7.0          NaN         NaN
# ..             ...                 ...          ...         ...
# 122            NaN                 NaN          NaN         NaN
# 123            NaN                 NaN          NaN         NaN
# 124            NaN                 NaN          NaN         NaN
# 125            NaN                 NaN          NaN         NaN
# 126            NaN                 NaN          NaN         NaN
#
#      Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# 0           1786.0             NaN              2977.0             NaN
# 1           1781.0             NaN              2943.0             NaN
# 2           1767.0          3496.0              2915.0             NaN
# 3              NaN          3496.0                 NaN             NaN
# 5           1739.0          3471.0              2827.0             NaN
# ..             ...             ...                 ...             ...
# 122           66.0             6.0                 5.0             NaN
# 123           62.0             NaN                 NaN             NaN
# 124           60.0             NaN                 NaN             NaN
# 125           59.0             NaN                 NaN             NaN
# 126           29.0             NaN                 NaN             NaN
#
#      Deaths_Senegal  Deaths_UnitedStates  Deaths_Spain  Deaths_Mali
# 0               NaN                  NaN           NaN          NaN
# 1               NaN                  NaN           NaN          NaN
# 2               NaN                  3.0           NaN          NaN
# 3               NaN                  8.0           NaN          NaN
# 5               NaN                  5.0           NaN          NaN
# ..              ...                  ...           ...          ...
# 122             NaN                  NaN           NaN          NaN
# 123             NaN                  NaN           NaN          NaN
# 124             NaN                  NaN           NaN          NaN
# 125             NaN                  NaN           NaN          NaN
# 126             NaN                  NaN           NaN          NaN
#
# [121 rows x 16 columns]

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>8. How would you treat the missing values from the reported cases of malaria from the United States of America?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
df2['Cases_Liberia']=df2['Cases_Liberia'].fillna(df2['Cases_Liberia'].median())
df2
# Out:
#      Cases_Guinea  Cases_Liberia  Cases_SierraLeone  Cases_Nigeria  \
# 0          2776.0          492.0            10030.0            NaN
# 1          2775.0          492.0             9780.0            NaN
# 2          2769.0         8166.0             9722.0            NaN
# 3             NaN         8157.0                NaN            NaN
# 5          2730.0         8115.0             9633.0            NaN
# ..            ...            ...                ...            ...
# 122         103.0            8.0                6.0            NaN
# 123          86.0          492.0                NaN            NaN
# 124          86.0          492.0                NaN            NaN
# 125          86.0          492.0                NaN            NaN
# 126          49.0          492.0                NaN            NaN
#
#      Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# 0              NaN                 NaN          NaN         NaN
# 1              NaN                 NaN          NaN         NaN
# 2              NaN                20.0          NaN         NaN
# 3              NaN                10.0          NaN         NaN
# 5              NaN                 7.0          NaN         NaN
# ..             ...                 ...          ...         ...
# 122            NaN                 NaN          NaN         NaN
# 123            NaN                 NaN          NaN         NaN
# 124            NaN                 NaN          NaN         NaN
# 125            NaN                 NaN          NaN         NaN
# 126            NaN                 NaN          NaN         NaN
#
#      Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# 0           1786.0             NaN              2977.0             NaN
# 1           1781.0             NaN              2943.0             NaN
# 2           1767.0          3496.0              2915.0             NaN
# 3              NaN          3496.0                 NaN             NaN
# 5           1739.0          3471.0              2827.0             NaN
# ..             ...             ...                 ...             ...
# 122           66.0             6.0                 5.0             NaN
# 123           62.0             NaN                 NaN             NaN
# 124           60.0             NaN                 NaN             NaN
# 125           59.0             NaN                 NaN             NaN
# 126           29.0             NaN                 NaN             NaN
#
#      Deaths_Senegal  Deaths_UnitedStates  Deaths_Spain  Deaths_Mali
# 0               NaN                  NaN           NaN          NaN
# 1               NaN                  NaN           NaN          NaN
# 2               NaN                  3.0           NaN          NaN
# 3               NaN                  8.0           NaN          NaN
# 5               NaN                  5.0           NaN          NaN
# ..              ...                  ...           ...          ...
# 122             NaN                  NaN           NaN          NaN
# 123             NaN                  NaN           NaN          NaN
# 124             NaN                  NaN           NaN          NaN
# 125             NaN                  NaN           NaN          NaN
# 126             NaN                  NaN           NaN          NaN
#
# [121 rows x 16 columns]

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>9. How should the missing values from the observations recorded in 'Guinea' be dealt with?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
df2['Cases_Guinea'].fillna(df['Cases_Guinea'].median())
df2
# Out:
#      Cases_Guinea  Cases_Liberia  Cases_SierraLeone  Cases_Nigeria  \
# 0          2776.0          492.0            10030.0            NaN
# 1          2775.0          492.0             9780.0            NaN
# 2          2769.0         8166.0             9722.0            NaN
# 3             NaN         8157.0                NaN            NaN
# 5          2730.0         8115.0             9633.0            NaN
# ..            ...            ...                ...            ...
# 122         103.0            8.0                6.0            NaN
# 123          86.0          492.0                NaN            NaN
# 124          86.0          492.0                NaN            NaN
# 125          86.0          492.0                NaN            NaN
# 126          49.0          492.0                NaN            NaN
#
#      Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# 0              NaN                 NaN          NaN         NaN
# 1              NaN                 NaN          NaN         NaN
# 2              NaN                20.0          NaN         NaN
# 3              NaN                10.0          NaN         NaN
# 5              NaN                 7.0          NaN         NaN
# ..             ...                 ...          ...         ...
# 122            NaN                 NaN          NaN         NaN
# 123            NaN                 NaN          NaN         NaN
# 124            NaN                 NaN          NaN         NaN
# 125            NaN                 NaN          NaN         NaN
# 126            NaN                 NaN          NaN         NaN
#
#      Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# 0           1786.0             NaN              2977.0             NaN
# 1           1781.0             NaN              2943.0             NaN
# 2           1767.0          3496.0              2915.0             NaN
# 3              NaN          3496.0                 NaN             NaN
# 5           1739.0          3471.0              2827.0             NaN
# ..             ...             ...                 ...             ...
# 122           66.0             6.0                 5.0             NaN
# 123           62.0             NaN                 NaN             NaN
# 124           60.0             NaN                 NaN             NaN
# 125           59.0             NaN                 NaN             NaN
# 126           29.0             NaN                 NaN             NaN
#
#      Deaths_Senegal  Deaths_UnitedStates  Deaths_Spain  Deaths_Mali
# 0               NaN                  NaN           NaN          NaN
# 1               NaN                  NaN           NaN          NaN
# 2               NaN                  3.0           NaN          NaN
# 3               NaN                  8.0           NaN          NaN
# 5               NaN                  5.0           NaN          NaN
# ..              ...                  ...           ...          ...
# 122             NaN                  NaN           NaN          NaN
# 123             NaN                  NaN           NaN          NaN
# 124             NaN                  NaN           NaN          NaN
# 125             NaN                  NaN           NaN          NaN
# 126             NaN                  NaN           NaN          NaN
#
# [121 rows x 16 columns]

# %% [markdown]
# ## For questions hereon, we shall consider the following dataset.

# %% [markdown]
# ### About the dataset (House Prices in Melbourne)
#
# The dataset contains different attributes that contribute to the price of the houses in Melbourne.
#
# Attribute Information:
#
# **Rooms**: Number of rooms
#
# **Type**: h - house,cottage,villa, semi,terrace; u - unit, duplex; t - townhouse; dev site - development site; o res - other residential.
#
# **Price**: Price in dollars
#
# **Method**: S - property sold; SP - property sold prior; PI - property passed in; PN - sold prior not disclosed; SN - sold not disclosed; NB - no bid; VB - vendor bid; W - withdrawn before auction; SA - sold after auction; SS - sold after auction price not disclosed. N/A - price or highest bid not available.
#
# **Regionname**:  General Region (West, North West, North, Northeast,...)
#
# **Bathroom**: Number of Bathrooms
#
# **Car**: Number of car spots
#
# **Landsize**: Land Size of a house
#
# **Distance**: Distance from CBD (City Centre)
#
# **Bedroom**: Number of Bedrooms

# %% [markdown]
# #### Load the house dataset and display the first five records (Use for section 3 to 6)

# %%
hp = pd.read_csv("house.csv")
hp.head()
# Out:
#    Rooms Type    Price Method             Regionname  Bathroom  Car  Landsize  \
# 0      3    h  1490000      S  Northern Metropolitan         1    1       126
# 1      3    h  1220000      S  Northern Metropolitan         1    1       202
# 2      3    h  1420000      S  Northern Metropolitan         1    0       156
# 3      3    h  1515000      S   Western Metropolitan         2    1         0
# 4      2    h   670000      S   Western Metropolitan         2    0       134
#
#    Distance  Bedroom
# 0      25.2        2
# 1      21.8        2
# 2      21.7        2
# 3      18.8        3
# 4      20.6        3

# %% [markdown]
# <a id="out"> </a>
# ## 3. Outlier Detection Techniques

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>10. Is there a feature in the dataset which could be exempted from outlier treatment?
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
hp[['Landsize','Distance']].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
hp.Landsize.plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>11. How do we check the outlier values for the feature representing the number of car spots?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
hp['Car'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>12. Compare the outliers present in the price of real estates by their type
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
df_mean2=hp['Price'].mean()
df_sigma2=hp['Price'].std()
ul2=df_mean2+3*df_sigma2
ll2=df_mean2-3*df_sigma2
df_out2=hp[(hp['Price']<ll2) | (hp['Price']>ul2)]
df_out2
# Out:
#       Rooms Type    Price Method                  Regionname  Bathroom  Car  \
# 39        4    h  3000000      S       Southern Metropolitan         1    1
# 49        4    h  2975000      S       Southern Metropolitan         1    1
# 82        7    h  4000000      S  South-Eastern Metropolitan         1    0
# 127       4    h  4150000      S       Northern Metropolitan         1    2
# 134       4    h  2985000      S       Southern Metropolitan         1    2
# ...     ...  ...      ...    ...                         ...       ...  ...
# 4272      4    h  3825000      S       Northern Metropolitan         2    1
# 4319      4    h  3680000     SP       Southern Metropolitan         1    1
# 4488      4    h  3100000     VB       Southern Metropolitan         2    2
# 4658      5    h  4515000     PI       Southern Metropolitan         1    2
# 4748      4    h  3600000     VB       Southern Metropolitan         2    1
#
#       Landsize  Distance  Bedroom
# 39         172      15.0        2
# 49         265      16.3        3
# 82         126      16.7        2
# 127        592      18.8        2
# 134        979      14.4        2
# ...        ...       ...      ...
# 4272       458      24.3        3
# 4319       237      30.0        2
# 4488       403      19.7        3
# 4658       219      18.1        4
# 4748       190      23.1        2
#
# [91 rows x 10 columns]

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>13. What would be the extreme values for the feature representing the number of rooms?
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
print(f"The min value of room is {hp['Rooms'].min():0.2f} and max value is {hp['Rooms'].max():0.2f}")
# Out:
# The min value of room is 1.00 and max value is 8.00

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>14. Suggest a method to find the outlier values for the feature representing the number of bathrooms
#  </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
hp['Bathroom'].value_counts()
df_mean=hp['Bathroom'].mean()
df_sigma=hp['Bathroom'].std()
ul=df_mean+3*df_sigma
ll=df_mean-3*df_sigma
df_out=hp[(hp['Bathroom']<ll) | (hp['Bathroom']>ul)]
df_out.head()
# Out:
#      Rooms Type    Price Method                  Regionname  Bathroom  Car  \
# 103      3    t   385000      S       Northern Metropolitan         7    0
# 122      3    t   950000      S        Eastern Metropolitan         4    4
# 229      1    u   337000      S  South-Eastern Metropolitan         4    2
# 382      3    h   720000      S        Western Metropolitan         5    2
# 448      3    h  1116000      S       Southern Metropolitan         5    4
#
#      Landsize  Distance  Bedroom
# 103       435      18.0        3
# 122       809      19.3        3
# 229       662      12.7        3
# 382       755      14.0        4
# 448       673      19.0        3

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>15. Extract the records corresponding to the extreme outliers present in the feature representing the number of bedrooms
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
df_mean3=hp['Bedroom'].mean()
df_sigma3=hp['Bedroom'].std()
ul3=df_mean3+3*df_sigma3
ll3=df_mean3-3*df_sigma3
df_out3=hp[(hp['Bedroom']<ll3) | (hp['Bedroom']>ul3)]
df_out3.head()
# Out:
#      Rooms Type    Price Method                  Regionname  Bathroom  Car  \
# 130      3    h   900000      S        Eastern Metropolitan         1    1
# 279      3    t  1100000      S       Southern Metropolitan         1    1
# 467      2    u   612000      S  South-Eastern Metropolitan         1    2
# 752      3    t   891000      S        Western Metropolitan         1    1
# 761      1    u   401000      S       Southern Metropolitan         1    2
#
#      Landsize  Distance  Bedroom
# 130       180      21.3        7
# 279         0      12.1        8
# 467       766      27.1        9
# 752       632      18.2        7
# 761       624      20.6        7

# %% [markdown]
# <a id="odt"> </a>
# ## 4. Treatment of Outliers

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>16. What is the change in the average distance after handling the outliers using IQR method in the feature representing the distance?
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
IQR=hp['Distance'].quantile(0.75)-hp['Distance'].quantile(0.25)
IQR
# Out:
# 5.699999999999999

# %%
hp[hp['Distance']<(hp['Distance'].quantile(0.75))+1.5*IQR]
# Out:
#       Rooms Type    Price Method                  Regionname  Bathroom  Car  \
# 0         3    h  1490000      S       Northern Metropolitan         1    1
# 1         3    h  1220000      S       Northern Metropolitan         1    1
# 2         3    h  1420000      S       Northern Metropolitan         1    0
# 3         3    h  1515000      S        Western Metropolitan         2    1
# 4         2    h   670000      S        Western Metropolitan         2    0
# ...     ...  ...      ...    ...                         ...       ...  ...
# 4761      3    h  1150000     VB       Southern Metropolitan         2    1
# 4762      3    h   712000      S  South-Eastern Metropolitan         1    0
# 4763      4    h   800000      S  South-Eastern Metropolitan         1    0
# 4764      3    u   747000      S  South-Eastern Metropolitan         1    1
# 4765      3    h   800000     SP  South-Eastern Metropolitan         1    1
#
#       Landsize  Distance  Bedroom
# 0          126      25.2        2
# 1          202      21.8        2
# 2          156      21.7        2
# 3            0      18.8        3
# 4          134      20.6        3
# ...        ...       ...      ...
# 4761       305      18.7        3
# 4762       105      16.0        4
# 4763       120      24.5        3
# 4764         0      22.9        3
# 4765         0      13.7        3
#
# [4747 rows x 10 columns]

# %%
hp[hp['Distance']<(hp['Distance'].quantile(0.25))-1.5*IQR]
# Out:
#       Rooms Type    Price Method                  Regionname  Bathroom  Car  \
# 343       3    t   667500     SP        Western Metropolitan         2    1
# 801       4    h  2500000      S       Southern Metropolitan         1    2
# 887       3    h  1130000      S  South-Eastern Metropolitan         2    2
# 1034      5    h  2260000      S       Southern Metropolitan         1    2
# 1332      2    t   675000     SP       Northern Metropolitan         2    1
# 1986      2    h  1330000      S       Southern Metropolitan         1    1
# 2123      3    h   905000      S       Northern Metropolitan         2    1
# 2316      3    u   554000      S        Western Metropolitan         1    1
# 2349      3    h  1035000      S  South-Eastern Metropolitan         1    0
# 2684      1    u   365000      S       Northern Metropolitan         1    1
# 4489      2    u   530000     VB       Southern Metropolitan         1    2
# 4636      4    h   685000      S        Western Metropolitan         1    1
#
#       Landsize  Distance  Bedroom
# 343          0       7.5        4
# 801        603       6.7        2
# 887        213       6.0        2
# 1034       432       7.0        3
# 1332       351       6.6        2
# 1986       416       7.1        3
# 2123         0       7.1        2
# 2316       553       7.1        2
# 2349       249       7.8        2
# 2684         0       5.0        3
# 4489       274       7.3        3
# 4636       253       6.3        5

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>17. What should be the range (K*IQR) considered to eliminate the extreme outliers for the feature representing the house price?
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
hp['Regionname']
# Out:
# 0            Northern Metropolitan
# 1            Northern Metropolitan
# 2            Northern Metropolitan
# 3             Western Metropolitan
# 4             Western Metropolitan
#                    ...
# 4761         Southern Metropolitan
# 4762    South-Eastern Metropolitan
# 4763    South-Eastern Metropolitan
# 4764    South-Eastern Metropolitan
# 4765    South-Eastern Metropolitan
# Name: Regionname, Length: 4766, dtype: object

# %% [markdown]
# <a id="fe"> </a>
# ## 5. Feature Engineering

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>18. Categorize the houses in three groups based on their distance from CBD and create a new feature containing the group labels
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>19. Compare the house prices based on the different distance levels
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

# %% [markdown]
# <a id="split"> </a>
# ## 6. Train-Test Split

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>20. Split the price of houses in the proportion 80:20
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
from sklearn.model_selection import train_test_split

# %%
x=hp.iloc[:,1:]
x.head()
# Out:
#   Type    Price Method             Regionname  Bathroom  Car  Landsize  \
# 0    h  1490000      S  Northern Metropolitan         1    1       126
# 1    h  1220000      S  Northern Metropolitan         1    1       202
# 2    h  1420000      S  Northern Metropolitan         1    0       156
# 3    h  1515000      S   Western Metropolitan         2    1         0
# 4    h   670000      S   Western Metropolitan         2    0       134
#
#    Distance  Bedroom
# 0      25.2        2
# 1      21.8        2
# 2      21.7        2
# 3      18.8        3
# 4      20.6        3

# %%
y=hp.iloc[:,0]
y.head()
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# 4    2
# Name: Rooms, dtype: int64

# %%
x_train, x_test, y_train, y_test= train_test_split(x,y,train_size=0.2, random_state=0)

# %%
x_train.shape
# Out:
# (953, 9)

# %%
y_train.shape
# Out:
# (953,)

# %%
x_test.shape
# Out:
# (3813, 9)

# %%
y_test.shape
# Out:
# (3813,)
